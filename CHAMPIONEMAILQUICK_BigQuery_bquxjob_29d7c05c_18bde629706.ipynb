# %% [markdown]
# <a href="https://colab.research.google.com/github/paigesgiese/big-query-inquiries/blob/main/CHAMPIONEMAILQUICK_BigQuery_bquxjob_29d7c05c_18bde629706.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Setup
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'btdatascience' # Project ID inserted based on the query results selected to explore
location = 'US' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %% [markdown]
# ## Reference SQL syntax from the original job
# Use the ```jobs.query```
# [method](https://cloud.google.com/bigquery/docs/reference/rest/v2/jobs/query) to
# return the SQL syntax from the job. This can be copied from the output cell
# below to edit the query now or in the future. Alternatively, you can use
# [this link](https://console.cloud.google.com/bigquery?j=btdatascience:US:bquxjob_29d7c05c_18bde629706)
# back to BigQuery to edit the query within the BigQuery user interface.

# %%
# Running this code will display the query used to generate your previous job

job = client.get_job('bquxjob_1ec57803_18bdeae0637') # Job ID inserted based on the query results selected to explore
print(job.query)
# Out:
# ---- CHAMPION REPORTING
# with
# email_activity as (
#   select
#     con.id as contact_id
#     , ac.id as account_id
#     , ac.builder_id_c as builder_id
#     , e.id as email_event_id
#     , e.event_date as email_sent_date
#     , em.id as email_id
#     , em.name as email_name
#     , ts.dynamic_email_subject as email_subject
#     , j.id as journey_id
#     , j.name as journey_name
#     --, a.*
#     , con.email
#     , con.email_2_c
#     , con.email_3_c
#     , con.btu_dates_c
#     , con.role_c
#     , ac.bt_champion_c
#
#     --,ARRAY(SELECT email_string FROM UNNEST(con.email) AS email_string) AS email_final
#   from
#     `salesforce_marketing_cloud.journey` j
#     join `salesforce_marketing_cloud.activity` a
#       on a.journey_id = j.id
#       and a.type LIKE 'EMAIL%' -- includes other activities, like sales events and wait times.
#       and a._fivetran_deleted is false
#     join `btdatascience.salesforce_marketing_cloud.triggered_send` ts
#       on ts.id = a.triggered_send_id
#     join `btdatascience.salesforce_marketing_cloud.event` e
#       on e.triggered_send_id = ts.id
#         and e.event_type = 'Sent' ---subscriber_key = unique, 'id' = unique
#     join `btdatascience.salesforce_marketing_cloud.email` em
#       on em.id = ts.email_id
#     join `btdatascience.salesforce.contact` con
#       on con.id = e.subscriber_key
#     join `btdatascience.salesforce.account` ac
#       on ac.id = con.account_id
#
#
#     --where j.id = '9a8eeb5c-4255-42ba-9fbf-0d94cf9a521c' -- onboarding journey
#     --and e.id ='9kJ3adMSSwyyjv0szw1NQHnn0ys=' --'dBD5BNL3tfigc+n1oh4b4c/kgMU=' -- ''---- looking for a specific email event
# ),
# --- Need to identify the control group tomorrow. This is the test group
#
# test_group as (
# select builder_id, min(email_sent_date) as first_email_sent, max(email_sent_date) as last_email_sent
# , count(distinct email_name) as ct_of_emails_sent
#  ,case when max(basic_email)=1
#   then'Basic'
#   when max(boost_email)=1
#   then 'Boost'
# end as test_group
# from (
#     select builder_id
#     , email_sent_date
#     , email_name
#     , case when email_name like '%Basic%'
#     then 1
#     end as basic_email
#     , case when email_name not like '%Basic%'
#     then 1
#     end as boost_email
#     from email_activity
#     where  lower(email_name) like '%btchamp%' --or lower(email_name) like '%onboard%')
# ) group by builder_id
#
# ),
# --- control group
# control as (
# select  ac.builder_id_c as builder_id
#  , min(email_sent_date) as first_email_sent, max(email_sent_date) as last_email_sent
# , count(distinct email_name) as ct_of_emails_sent
# , 'Control' as test_group
# from
#   `salesforce.campaign_member` cm
#   join `salesforce.contact` con
#     on con.id = cm.contact_id
#  join `btdatascience.salesforce.account` ac
#       on ac.id = con.account_id
# join email_activity ea on ea.builder_id = ac.builder_id_c
# and lower(email_name) like '%onboard%'
# where
#   cm.campaign_id = '701Qg00000338AcIAI' --"buildertrend_champion_onboarding" campaign for control group
#   group by ac.builder_id_c
# ),
#
# final_membership as (
#     select * from test_group
#     UNION ALL
#     select * from control
# ), --select test_group, count(*) from final_membership group by test_group
#
# fin as (
# select tg.*
# , h.builder_rewin -- just get the rewin number
# , h.implement_entrance_date
# , h.adopt_entrance_date
# , h.commit_score
# , h.snapshot_journey_stage
# , row_number() over(partition by cast(tg.builder_id as string) order by h.record_date asc) as rk
# --, min(cast(h.record_date as date)) over(partition by builder_id)
# from final_membership tg
# join `btdwh-prod-project.customer_health.builder_health__daily` h on h.builder_id = tg.builder_id
#     and (cast(h.record_date as date) >= cast(tg.first_email_sent as date)
#     OR cast(h.record_date as date) = date_add(cast(tg.first_email_sent as date), interval 1 DAY))
# /*join `btdwh-prod-project.customers.builders_buildertrend_mack__monthly` m on m.builder_id = tg.builder_id
# where is_demo_account is false
# and is_unbilled is false
# and is_website_only is false*/
# ),
# -- 6 builders got excluded bc they're not in the mack or builder health
# health as (
# select a.*
# , h.commit_score as first_commit_score
# , h2.commit_score as last_commit_score
# , h.implement_entrance_date
# , h.adopt_entrance_date
# , h2.snapshot_journey_stage as max_journey_stage
# , h2.completed_workflows
# from (
# select f.builder_rewin, first_email_sent, last_email_sent, ct_of_emails_sent,test_group
# , min(record_date) as first_commit_score_date
# , max(record_date) as last_commit_score_date
# from fin f
# join `btdwh-prod-project.customer_health.builder_health__daily` h on h.builder_rewin = f.builder_rewin and h.commit_score is not null
# group by f.builder_rewin, first_email_sent, last_email_sent, ct_of_emails_sent,test_group
# ) a
# left join `btdwh-prod-project.customer_health.builder_health__daily` h on h.builder_rewin = a.builder_rewin and h.record_date  = a.first_commit_score_date
# left join `btdwh-prod-project.customer_health.builder_health__daily` h2 on h2.builder_rewin = a.builder_rewin and h2.record_date  = a.last_commit_score_date
# )
#
# select f.builder_rewin, f.first_email_sent, f.last_email_sent, f.ct_of_emails_sent,f.test_group
# , h.first_commit_score_date
# , h.last_commit_score_date
# , h.first_commit_score
# , h.last_commit_score
# , f.implement_entrance_date
# --, f.adopt_entrance_date
# , h.max_journey_stage
# , h.completed_workflows
# , signup_package
# , billing_cycle
# , new_logo_at_cst
# , customer_journey_stage
# , customer_journey_stage_entered_at
# from fin f
# left join  health h on h.builder_rewin = f.builder_rewin
# left join `btdwh-prod-project.customers.builders_buildertrend_mack__monthly` m on m.builder_rewin_id = f.builder_rewin
#     and is_to_date is true
# where rk =1

# %% [markdown]
# # Result set loaded from BigQuery job as a DataFrame
# Query results are referenced from the Job ID ran from BigQuery and the query
# does not need to be re-run to explore results. The ```to_dataframe```
# [method](https://googleapis.dev/python/bigquery/latest/generated/google.cloud.bigquery.job.QueryJob.html#google.cloud.bigquery.job.QueryJob.to_dataframe)
# downloads the results to a Pandas DataFrame by using the BigQuery Storage API.
#
# To edit query syntax, you can do so from the BigQuery SQL editor or in the
# ```Optional:``` sections below.

# %%
# Running this code will read results from your previous job

job = client.get_job('bquxjob_89eb661_18bdec2c6e6') # Job ID inserted based on the query results selected to explore
results = job.to_dataframe()
results
# Out:
#     builder_rewin        first_email_sent         last_email_sent  \
# 0        100061-0 2023-11-09 12:39:47.370 2023-11-16 10:47:04.737
# 1        100130-0 2023-11-13 15:39:58.617 2023-11-15 15:41:11.473
# 2        100137-0 2023-11-13 17:39:14.430 2023-11-15 17:40:12.013
# 3        100170-0 2023-11-14 21:39:51.537 2023-11-15 21:40:03.523
# 4         99857-0 2023-11-01 09:40:46.910 2023-11-05 09:43:06.337
# ..            ...                     ...                     ...
# 315       99918-0 2023-11-03 10:40:02.887 2023-11-09 10:41:15.873
# 316       75148-1 2023-11-13 23:40:15.477 2023-11-16 23:42:07.667
# 317       99880-0 2023-11-01 15:40:11.720 2023-11-05 15:42:09.523
# 318       99949-0 2023-11-03 19:39:32.100 2023-11-08 19:42:13.777
# 319       99990-0 2023-11-07 05:39:43.250 2023-11-12 05:42:22.470
#
#      ct_of_emails_sent test_group first_commit_score_date  \
# 0                    3      Boost              2023-11-10
# 1                    3      Boost              2023-11-16
# 2                    3      Boost              2023-11-16
# 3                    2      Basic              2023-11-16
# 4                    4      Boost              2023-11-02
# ..                 ...        ...                     ...
# 315                  3    Control              2023-11-05
# 316                  3      Basic              2023-11-16
# 317                  4      Boost              2023-11-02
# 318                  4      Basic              2023-11-05
# 319                  4      Basic              2023-11-08
#
#     last_commit_score_date  first_commit_score  last_commit_score  \
# 0               2023-11-16                   3                 11
# 1               2023-11-16                  11                 11
# 2               2023-11-16                  29                 29
# 3               2023-11-16                   0                  0
# 4               2023-11-16                   1                 64
# ..                     ...                 ...                ...
# 315             2023-11-16                   7                  4
# 316             2023-11-16                   1                  1
# 317             2023-11-16                   1                  0
# 318             2023-11-16                   2                  1
# 319             2023-11-16                   1                  0
#
#     implement_entrance_date max_journey_stage  completed_workflows  \
# 0                2023-11-09         implement                    0
# 1                2023-11-13         implement                    0
# 2                2023-11-13         implement                    1
# 3                2023-11-14         implement                    0
# 4                2023-11-01             adopt                    1
# ..                      ...               ...                  ...
# 315              2023-11-03         implement                    0
# 316              2023-11-13         implement                    0
# 317              2023-11-01         implement                    0
# 318              2023-11-03         implement                    0
# 319              2023-11-07         implement                    0
#
#         signup_package  billing_cycle     new_logo_at_cst  \
# 0      Essential-Boost              1 2023-11-09 11:32:50
# 1     Advanced-Boost12             12 2023-11-13 14:23:33
# 2    Essential-Boost12             12 2023-11-13 16:44:56
# 3       Advanced-Basic              1 2023-11-14 20:23:09
# 4      Essential-Boost              1 2023-11-01 09:36:18
# ..                 ...            ...                 ...
# 315    Essential-Boost              1 2023-11-03 10:06:59
# 316     Advanced-Basic              1 2023-11-13 23:03:11
# 317    Essential-Boost              1 2023-11-01 16:14:14
# 318    Essential-Basic              1 2023-11-03 20:02:05
# 319    Essential-Basic              1 2023-11-07 04:20:22
#
#     customer_journey_stage customer_journey_stage_entered_at  \
# 0                Implement         2023-11-09 00:00:00+00:00
# 1                Implement         2023-11-13 00:00:00+00:00
# 2                Implement         2023-11-13 00:00:00+00:00
# 3                Implement         2023-11-14 00:00:00+00:00
# 4                    Adopt         2023-11-09 00:00:00+00:00
# ..                     ...                               ...
# 315              Implement         2023-11-03 00:00:00+00:00
# 316              Implement         2023-11-13 00:00:00+00:00
# 317              Implement         2023-11-01 00:00:00+00:00
# 318              Implement         2023-11-03 00:00:00+00:00
# 319              Implement         2023-11-07 00:00:00+00:00
#
#     churn_initiated_at_cst
# 0                      NaT
# 1                      NaT
# 2                      NaT
# 3                      NaT
# 4                      NaT
# ..                     ...
# 315                    NaT
# 316                    NaT
# 317                    NaT
# 318    2023-11-09 18:11:14
# 319                    NaT
#
# [320 rows x 18 columns]

# %%
results.groupby('test_group')['signup_package'].value_counts()
# Out:
# test_group  signup_package
# Basic       Essential-Basic       35
#             Advanced-Basic        15
#             Complete-Basic         3
#             Complete               2
# Boost       Essential-Boost      103
#             Advanced-Boost        65
#             Advanced-Boost12      25
#             Complete-Boost        16
#             Essential-Boost12     16
#             Complete-Boost12       7
# Control     Essential-Boost       13
#             Advanced-Boost         9
#             Advanced-Boost12       4
#             Advanced-Basic         3
#             Essential-Basic        3
#             Complete-Boost12       1
# Name: signup_package, dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = results.copy()
df['has_boost'] = np.where(df['signup_package'].str.contains('Boost'),1,0)

# %%
df.groupby('test_group')['has_boost'].mean()
# Out:
# test_group
# Basic      0.000000
# Boost      1.000000
# Control    0.818182
# Name: has_boost, dtype: float64

# %%
df['implement_week'] = pd.to_datetime(df['implement_entrance_date']).dt.weekofyear
df.groupby(['test_group'])['implement_week'].value_counts(normalize=True)
# Out:
# <ipython-input-80-5b0c06f5f187>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['implement_week'] = pd.to_datetime(df['implement_entrance_date']).dt.weekofyear
# test_group  implement_week
# Basic       45                0.418182
#             44                0.400000
#             46                0.181818
# Boost       45                0.435345
#             46                0.297414
#             44                0.267241
# Control     45                0.424242
#             46                0.303030
#             44                0.272727
# Name: implement_week, dtype: float64

# %%
df['test_group_2'] = None
df.loc[df['test_group']=='Basic','test_group_2'] = 'Basic'
df.loc[df['test_group']=='Boost','test_group_2'] = 'Boost'
df.loc[(df['test_group']=='Control')
& (df['has_boost']==1),'test_group_2'] = 'Control - Boost'
df.loc[(df['test_group']=='Control')
& (df['has_boost']==0),'test_group_2'] = 'Control - Basic'

## Looking at workflow completions
df['completed_workflows'].fillna(0, inplace=True)
df.groupby('test_group_2')['completed_workflows'].sum()/df.groupby('test_group_2')['builder_rewin'].nunique()
# Out:
# test_group_2
# Basic              0.127273
# Boost              0.155172
# Control - Basic         0.0
# Control - Boost    0.259259
# dtype: Float64

# %%
df['workflowed'] = np.where(df['completed_workflows']>0,1,0)
df.groupby('test_group_2')['workflowed'].mean()
# Out:
# test_group_2
# Basic              0.127273
# Boost              0.120690
# Control - Basic    0.000000
# Control - Boost    0.222222
# Name: workflowed, dtype: float64

# %%
#df['ooimplement'] = df['adopt_entrance_date'].notnull()
df.groupby('test_group_2')['customer_journey_stage'].value_counts()
df['exits'] = np.where(df['customer_journey_stage'] == 'Adopt',1,0)

# %%
df.groupby('test_group_2')['max_journey_stage'].value_counts(normalize=True)
# Out:
# test_group_2     max_journey_stage
# Basic            implement            0.880000
#                  adopt                0.120000
# Boost            implement            0.925373
#                  adopt                0.074627
# Control - Basic  implement            1.000000
# Control - Boost  implement            0.960000
#                  adopt                0.040000
# Name: max_journey_stage, dtype: float64

# %%
df['new_logo_at_cst']
# Out:
# 0     2023-11-09 11:32:50
# 1     2023-11-13 14:23:33
# 2     2023-11-13 16:44:56
# 3     2023-11-14 20:23:09
# 4     2023-11-01 09:36:18
#               ...
# 315   2023-11-03 10:06:59
# 316   2023-11-13 23:03:11
# 317   2023-11-01 16:14:14
# 318   2023-11-03 20:02:05
# 319   2023-11-07 04:20:22
# Name: new_logo_at_cst, Length: 320, dtype: datetime64[ns]

# %%
import datetime
df['today'] = (pd.to_datetime(datetime.datetime.utcnow()).tz_localize('UTC').tz_convert('US/Central'))
df['daysInBT'] = round((df['today'] - pd.to_datetime(df['new_logo_at_cst']).dt.tz_localize('US/Central'))/pd.Timedelta(1,'D'))

# %%
df.groupby('test_group_2')['daysInBT'].mean()
# Out:
# test_group_2
# Basic              10.072727
# Boost               8.663793
# Control - Basic     8.833333
# Control - Boost     8.592593
# Name: daysInBT, dtype: float64

# %%
pd.to_datetime(df['new_logo_at_cst'])
# Out:
# 0     2023-11-03 08:35:07.000
# 1     2023-11-10 14:40:00.000
# 2     2023-11-13 10:39:09.000
# 3     2023-11-03 10:06:59.000
# 4     2023-11-08 16:07:39.000
#                 ...
# 315   2023-11-02 10:27:05.000
# 316   2023-11-06 11:47:54.000
# 317   2023-11-06 11:48:00.000
# 318   2023-11-06 13:51:13.137
# 319   2023-11-06 21:20:10.000
# Name: new_logo_at_cst, Length: 320, dtype: datetime64[ns]

# %%
df['churn_init'] = np.where(df['churn_initiated_at_cst'].notnull(),1,0)

# %%
df.groupby('test_group_2')['churn_init'].mean()
# Out:
# test_group_2
# Basic              0.036364
# Boost              0.064655
# Control - Basic    0.333333
# Control - Boost    0.037037
# Name: churn_init, dtype: float64

# %%
df['length_of_journey'] = 5
df.loc[df['test_group']=='Control','length_of_journey']=7

df['emails_in_journey'] = 4
df.loc[df['test_group']=='Control','emails_in_journey']=3
df['commit_score_change'] = df['last_commit_score']-df['first_commit_score']

# %%
df.groupby('test_group_2').agg({'builder_rewin':'count'
                                ,'length_of_journey':'max'
                                ,'emails_in_journey':'max'
                                ,'workflowed':'mean'
                                ,'first_commit_score':'median'
                                ,'last_commit_score':'median'
                                ,'commit_score_change':'median'
                                # ,'first_commit_score':'mean'
                                # ,'last_commit_score':'mean'
                                # ,'commit_score_change':'mean'
                                , 'exits':'mean'
                                ,'churn_init':'mean'
                                })
# Out:
#                  builder_rewin  length_of_journey  emails_in_journey  \
# test_group_2
# Basic                       55                  5                  4
# Boost                      232                  5                  4
# Control - Basic              6                  7                  3
# Control - Boost             27                  7                  3
#
#                  workflowed  first_commit_score  last_commit_score  \
# test_group_2
# Basic              0.127273                 2.0                4.0
# Boost              0.120690                 2.0                5.0
# Control - Basic    0.000000                 1.5                0.5
# Control - Boost    0.222222                 2.0                1.0
#
#                  commit_score_change     exits  churn_init
# test_group_2
# Basic                            0.0  0.109091    0.036364
# Boost                            0.0  0.064655    0.064655
# Control - Basic                 -0.5  0.000000    0.333333
# Control - Boost                  0.0  0.037037    0.037037

# %%
df['new_logo_at_cst'].max()
# Out:
# Timestamp('2023-11-16 18:42:48')
